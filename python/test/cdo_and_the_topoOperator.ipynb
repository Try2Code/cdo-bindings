# %%
from cdo import *

# %%
import matplotlib

# %%
topo = cdo.topo(options='-f nc',returnArray='topo')

# %%
cdo = Cdo()

# %%
imshow()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f38021ca65b0> in <module>()
# ----> 1 imshow()
#
# NameError: name 'imshow' is not defined

# %%
from matplotlib import pylab

# %%
pylab.imshow(topo)

# %%
# %matplotlib inline

# %%
oro = cdo.setrtomiss(-20000,0,input='-topo',options='-f nc', returnMaArray='topo')

# %%
import numpy
pylab.imshow(oro)

# %%
pylab.imshow(numpy.flipud(oro))
